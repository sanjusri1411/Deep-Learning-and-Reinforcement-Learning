# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.datasets import fashion_mnist
from tensorflow.keras.models import Model
from tensorflow.keras.layers import (Dense, Input, Add, BatchNormalization, Dropout,
                                     Activation, GaussianNoise, LeakyReLU)
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.optimizers import Adam

# %%
(x_train, y_train), (x_test, y_test) = fashion_mnist.load_data()
x_train = x_train.astype('float32') / 255.0
x_test = x_test.astype('float32') / 255.0
x_train_flat = x_train.reshape(-1, 784)
x_test_flat = x_test.reshape(-1, 784)
y_train = to_categorical(y_train, 10)
y_test = to_categorical(y_test, 10)

# %%
def create_advanced_dense_resnet():
    inputs = Input(shape=(784,))
    x = GaussianNoise(0.1)(inputs)
    x = Dense(1024)(x)
    x = BatchNormalization()(x)
    x = LeakyReLU()(x)

    def res_block(x, units):
        shortcut = Dense(units)(x)
        x1 = Dense(units)(x)
        x1 = BatchNormalization()(x1)
        x1 = LeakyReLU()(x1)
        x2 = Dense(units)(x1)
        x2 = BatchNormalization()(x2)
        out = Add()([shortcut, x2])
        out = LeakyReLU()(out)
        out = Dropout(0.4)(out)
        return out

    x = res_block(x, 512)
    x = res_block(x, 512)
    x = res_block(x, 256)
    x = res_block(x, 128)
    x = res_block(x, 64)
    x = res_block(x, 64)

    x = Dense(64)(x)
    x = LeakyReLU()(x)
    outputs = Dense(10, activation='softmax')(x)

    return Model(inputs, outputs)

# %%
model = create_advanced_dense_resnet()
optimizer = Adam(learning_rate=0.0008)

model.compile(optimizer=optimizer,
              loss='categorical_crossentropy',
              metrics=['accuracy'])
model.summary()
# Out:
# Model: "functional_2"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_2       │ (None, 784)       │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ gaussian_noise      │ (None, 784)       │          0 │ input_layer_2[0]… │
# │ (GaussianNoise)     │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_27 (Dense)    │ (None, 1024)      │    803,840 │ gaussian_noise[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 1024)      │      4,096 │ dense_27[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu         │ (None, 1024)      │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_29 (Dense)    │ (None, 512)       │    524,800 │ leaky_re_lu[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 512)       │      2,048 │ dense_29[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_1       │ (None, 512)       │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_30 (Dense)    │ (None, 512)       │    262,656 │ leaky_re_lu_1[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_28 (Dense)    │ (None, 512)       │    524,800 │ leaky_re_lu[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 512)       │      2,048 │ dense_30[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_9 (Add)         │ (None, 512)       │          0 │ dense_28[0][0],   │
# │                     │                   │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_2       │ (None, 512)       │          0 │ add_9[0][0]       │
# │ (LeakyReLU)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_15          │ (None, 512)       │          0 │ leaky_re_lu_2[0]… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_32 (Dense)    │ (None, 512)       │    262,656 │ dropout_15[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 512)       │      2,048 │ dense_32[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_3       │ (None, 512)       │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_33 (Dense)    │ (None, 512)       │    262,656 │ leaky_re_lu_3[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_31 (Dense)    │ (None, 512)       │    262,656 │ dropout_15[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 512)       │      2,048 │ dense_33[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_10 (Add)        │ (None, 512)       │          0 │ dense_31[0][0],   │
# │                     │                   │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_4       │ (None, 512)       │          0 │ add_10[0][0]      │
# │ (LeakyReLU)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_16          │ (None, 512)       │          0 │ leaky_re_lu_4[0]… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_35 (Dense)    │ (None, 256)       │    131,328 │ dropout_16[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256)       │      1,024 │ dense_35[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_5       │ (None, 256)       │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_36 (Dense)    │ (None, 256)       │     65,792 │ leaky_re_lu_5[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_34 (Dense)    │ (None, 256)       │    131,328 │ dropout_16[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256)       │      1,024 │ dense_36[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_11 (Add)        │ (None, 256)       │          0 │ dense_34[0][0],   │
# │                     │                   │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_6       │ (None, 256)       │          0 │ add_11[0][0]      │
# │ (LeakyReLU)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_17          │ (None, 256)       │          0 │ leaky_re_lu_6[0]… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_38 (Dense)    │ (None, 128)       │     32,896 │ dropout_17[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128)       │        512 │ dense_38[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_7       │ (None, 128)       │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_39 (Dense)    │ (None, 128)       │     16,512 │ leaky_re_lu_7[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_37 (Dense)    │ (None, 128)       │     32,896 │ dropout_17[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128)       │        512 │ dense_39[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_12 (Add)        │ (None, 128)       │          0 │ dense_37[0][0],   │
# │                     │                   │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_8       │ (None, 128)       │          0 │ add_12[0][0]      │
# │ (LeakyReLU)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_18          │ (None, 128)       │          0 │ leaky_re_lu_8[0]… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_41 (Dense)    │ (None, 64)        │      8,256 │ dropout_18[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64)        │        256 │ dense_41[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_9       │ (None, 64)        │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_42 (Dense)    │ (None, 64)        │      4,160 │ leaky_re_lu_9[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_40 (Dense)    │ (None, 64)        │      8,256 │ dropout_18[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64)        │        256 │ dense_42[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_13 (Add)        │ (None, 64)        │          0 │ dense_40[0][0],   │
# │                     │                   │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_10      │ (None, 64)        │          0 │ add_13[0][0]      │
# │ (LeakyReLU)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_19          │ (None, 64)        │          0 │ leaky_re_lu_10[0… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_44 (Dense)    │ (None, 64)        │      4,160 │ dropout_19[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64)        │        256 │ dense_44[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_11      │ (None, 64)        │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_45 (Dense)    │ (None, 64)        │      4,160 │ leaky_re_lu_11[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_43 (Dense)    │ (None, 64)        │      4,160 │ dropout_19[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64)        │        256 │ dense_45[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_14 (Add)        │ (None, 64)        │          0 │ dense_43[0][0],   │
# │                     │                   │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_12      │ (None, 64)        │          0 │ add_14[0][0]      │
# │ (LeakyReLU)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_20          │ (None, 64)        │          0 │ leaky_re_lu_12[0… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_46 (Dense)    │ (None, 64)        │      4,160 │ dropout_20[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_13      │ (None, 64)        │          0 │ dense_46[0][0]    │
# │ (LeakyReLU)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_47 (Dense)    │ (None, 10)        │        650 │ leaky_re_lu_13[0… │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 3,369,162 (12.85 MB)
#  Trainable params: 3,360,970 (12.82 MB)
#  Non-trainable params: 8,192 (32.00 KB)

# %%
lr_scheduler = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=3, verbose=1)
early_stop = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True, verbose=1)

# %%
history = model.fit(x_train_flat, y_train,
                    validation_split=0.2,
                    epochs=70,
                    batch_size=64,
                    callbacks=[lr_scheduler, early_stop],
                    verbose=2)
# Out:
# Epoch 1/70
# 750/750 - 63s - 84ms/step - accuracy: 0.6522 - loss: 1.0092 - val_accuracy: 0.8147 - val_loss: 0.5386 - learning_rate: 8.0000e-04
# Epoch 2/70
# 750/750 - 81s - 108ms/step - accuracy: 0.7790 - loss: 0.6477 - val_accuracy: 0.8447 - val_loss: 0.4481 - learning_rate: 8.0000e-04
# Epoch 3/70
# 750/750 - 49s - 65ms/step - accuracy: 0.8079 - loss: 0.5826 - val_accuracy: 0.8238 - val_loss: 0.5356 - learning_rate: 8.0000e-04
# Epoch 4/70
# 750/750 - 49s - 65ms/step - accuracy: 0.8195 - loss: 0.5485 - val_accuracy: 0.8049 - val_loss: 0.5037 - learning_rate: 8.0000e-04
# Epoch 5/70
# 750/750 - 83s - 111ms/step - accuracy: 0.8255 - loss: 0.5271 - val_accuracy: 0.8572 - val_loss: 0.4187 - learning_rate: 8.0000e-04
# Epoch 6/70
# 750/750 - 50s - 67ms/step - accuracy: 0.8362 - loss: 0.4985 - val_accuracy: 0.8658 - val_loss: 0.3882 - learning_rate: 8.0000e-04
# Epoch 7/70
# 750/750 - 80s - 107ms/step - accuracy: 0.8427 - loss: 0.4771 - val_accuracy: 0.8556 - val_loss: 0.4178 - learning_rate: 8.0000e-04
# Epoch 8/70
# 750/750 - 82s - 110ms/step - accuracy: 0.8473 - loss: 0.4582 - val_accuracy: 0.8491 - val_loss: 0.4333 - learning_rate: 8.0000e-04
# Epoch 9/70
# 750/750 - 83s - 111ms/step - accuracy: 0.8511 - loss: 0.4493 - val_accuracy: 0.8665 - val_loss: 0.3785 - learning_rate: 8.0000e-04
# Epoch 10/70
# 750/750 - 80s - 107ms/step - accuracy: 0.8544 - loss: 0.4359 - val_accuracy: 0.8721 - val_loss: 0.3840 - learning_rate: 8.0000e-04
# Epoch 11/70
# 750/750 - 81s - 109ms/step - accuracy: 0.8554 - loss: 0.4269 - val_accuracy: 0.8682 - val_loss: 0.3765 - learning_rate: 8.0000e-04
# Epoch 12/70
# 750/750 - 84s - 112ms/step - accuracy: 0.8606 - loss: 0.4148 - val_accuracy: 0.8690 - val_loss: 0.3880 - learning_rate: 8.0000e-04
# Epoch 13/70
# 750/750 - 79s - 105ms/step - accuracy: 0.8631 - loss: 0.4115 - val_accuracy: 0.8717 - val_loss: 0.3656 - learning_rate: 8.0000e-04
# Epoch 14/70
# 750/750 - 82s - 110ms/step - accuracy: 0.8648 - loss: 0.4021 - val_accuracy: 0.8776 - val_loss: 0.3527 - learning_rate: 8.0000e-04
# Epoch 15/70
# 750/750 - 80s - 107ms/step - accuracy: 0.8669 - loss: 0.3958 - val_accuracy: 0.8844 - val_loss: 0.3367 - learning_rate: 8.0000e-04
# Epoch 16/70
# 750/750 - 82s - 110ms/step - accuracy: 0.8692 - loss: 0.3917 - val_accuracy: 0.8691 - val_loss: 0.3804 - learning_rate: 8.0000e-04
# Epoch 17/70
# 750/750 - 82s - 109ms/step - accuracy: 0.8720 - loss: 0.3794 - val_accuracy: 0.8838 - val_loss: 0.3397 - learning_rate: 8.0000e-04
# Epoch 18/70
#
# Epoch 18: ReduceLROnPlateau reducing learning rate to 0.00039999998989515007.
# 750/750 - 82s - 109ms/step - accuracy: 0.8730 - loss: 0.3750 - val_accuracy: 0.8841 - val_loss: 0.3414 - learning_rate: 8.0000e-04
# Epoch 19/70
# 750/750 - 81s - 109ms/step - accuracy: 0.8867 - loss: 0.3294 - val_accuracy: 0.8899 - val_loss: 0.3397 - learning_rate: 4.0000e-04
# Epoch 20/70
# 750/750 - 83s - 110ms/step - accuracy: 0.8908 - loss: 0.3178 - val_accuracy: 0.8899 - val_loss: 0.3239 - learning_rate: 4.0000e-04
# Epoch 21/70
# 750/750 - 82s - 109ms/step - accuracy: 0.8905 - loss: 0.3117 - val_accuracy: 0.8897 - val_loss: 0.3186 - learning_rate: 4.0000e-04
# Epoch 22/70
# 750/750 - 46s - 62ms/step - accuracy: 0.8933 - loss: 0.3090 - val_accuracy: 0.8840 - val_loss: 0.3308 - learning_rate: 4.0000e-04
# Epoch 23/70
# 750/750 - 47s - 63ms/step - accuracy: 0.8938 - loss: 0.3025 - val_accuracy: 0.8902 - val_loss: 0.3195 - learning_rate: 4.0000e-04
# Epoch 24/70
#
# Epoch 24: ReduceLROnPlateau reducing learning rate to 0.00019999999494757503.
# 750/750 - 82s - 109ms/step - accuracy: 0.8957 - loss: 0.2999 - val_accuracy: 0.8800 - val_loss: 0.3560 - learning_rate: 4.0000e-04
# Epoch 25/70
# 750/750 - 47s - 62ms/step - accuracy: 0.9020 - loss: 0.2790 - val_accuracy: 0.8945 - val_loss: 0.3022 - learning_rate: 2.0000e-04
# Epoch 26/70
# 750/750 - 47s - 63ms/step - accuracy: 0.9035 - loss: 0.2742 - val_accuracy: 0.8925 - val_loss: 0.3051 - learning_rate: 2.0000e-04
# Epoch 27/70
# 750/750 - 83s - 111ms/step - accuracy: 0.9054 - loss: 0.2639 - val_accuracy: 0.8956 - val_loss: 0.3049 - learning_rate: 2.0000e-04
# Epoch 28/70
#
# Epoch 28: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-05.
# 750/750 - 84s - 112ms/step - accuracy: 0.9068 - loss: 0.2639 - val_accuracy: 0.8953 - val_loss: 0.3060 - learning_rate: 2.0000e-04
# Epoch 29/70
# 750/750 - 80s - 107ms/step - accuracy: 0.9108 - loss: 0.2505 - val_accuracy: 0.8973 - val_loss: 0.3004 - learning_rate: 1.0000e-04
# Epoch 30/70
# 750/750 - 82s - 109ms/step - accuracy: 0.9130 - loss: 0.2439 - val_accuracy: 0.8980 - val_loss: 0.3049 - learning_rate: 1.0000e-04
# Epoch 31/70
# 750/750 - 48s - 65ms/step - accuracy: 0.9115 - loss: 0.2469 - val_accuracy: 0.8957 - val_loss: 0.2972 - learning_rate: 1.0000e-04
# Epoch 32/70
# 750/750 - 47s - 63ms/step - accuracy: 0.9146 - loss: 0.2409 - val_accuracy: 0.8992 - val_loss: 0.2980 - learning_rate: 1.0000e-04
# Epoch 33/70
# 750/750 - 83s - 111ms/step - accuracy: 0.9143 - loss: 0.2401 - val_accuracy: 0.8984 - val_loss: 0.3054 - learning_rate: 1.0000e-04
# Epoch 34/70
#
# Epoch 34: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 750/750 - 82s - 109ms/step - accuracy: 0.9143 - loss: 0.2399 - val_accuracy: 0.8979 - val_loss: 0.2983 - learning_rate: 1.0000e-04
# Epoch 35/70
# 750/750 - 81s - 108ms/step - accuracy: 0.9152 - loss: 0.2334 - val_accuracy: 0.9011 - val_loss: 0.2948 - learning_rate: 5.0000e-05
# Epoch 36/70
# 750/750 - 83s - 111ms/step - accuracy: 0.9189 - loss: 0.2300 - val_accuracy: 0.9010 - val_loss: 0.2974 - learning_rate: 5.0000e-05
# Epoch 37/70
# 750/750 - 82s - 109ms/step - accuracy: 0.9190 - loss: 0.2294 - val_accuracy: 0.9015 - val_loss: 0.2915 - learning_rate: 5.0000e-05
# Epoch 38/70
# 750/750 - 50s - 67ms/step - accuracy: 0.9171 - loss: 0.2306 - val_accuracy: 0.8991 - val_loss: 0.2921 - learning_rate: 5.0000e-05
# Epoch 39/70
# 750/750 - 50s - 67ms/step - accuracy: 0.9197 - loss: 0.2254 - val_accuracy: 0.8998 - val_loss: 0.2942 - learning_rate: 5.0000e-05
# Epoch 40/70
#
# Epoch 40: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# 750/750 - 80s - 107ms/step - accuracy: 0.9201 - loss: 0.2228 - val_accuracy: 0.8988 - val_loss: 0.2979 - learning_rate: 5.0000e-05
# Epoch 41/70
# 750/750 - 82s - 109ms/step - accuracy: 0.9193 - loss: 0.2219 - val_accuracy: 0.9011 - val_loss: 0.2937 - learning_rate: 2.5000e-05
# Epoch 42/70
# 750/750 - 81s - 108ms/step - accuracy: 0.9190 - loss: 0.2223 - val_accuracy: 0.9008 - val_loss: 0.2937 - learning_rate: 2.5000e-05
# Epoch 43/70
#
# Epoch 43: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
# 750/750 - 83s - 111ms/step - accuracy: 0.9223 - loss: 0.2225 - val_accuracy: 0.9010 - val_loss: 0.2931 - learning_rate: 2.5000e-05
# Epoch 44/70
# 750/750 - 82s - 109ms/step - accuracy: 0.9225 - loss: 0.2165 - val_accuracy: 0.9011 - val_loss: 0.2927 - learning_rate: 1.2500e-05
# Epoch 45/70
# 750/750 - 81s - 108ms/step - accuracy: 0.9221 - loss: 0.2142 - val_accuracy: 0.9003 - val_loss: 0.2954 - learning_rate: 1.2500e-05
# Epoch 46/70
#
# Epoch 46: ReduceLROnPlateau reducing learning rate to 6.24999984211172e-06.
# 750/750 - 83s - 110ms/step - accuracy: 0.9217 - loss: 0.2176 - val_accuracy: 0.9013 - val_loss: 0.2939 - learning_rate: 1.2500e-05
# Epoch 47/70
# 750/750 - 82s - 110ms/step - accuracy: 0.9220 - loss: 0.2139 - val_accuracy: 0.9010 - val_loss: 0.2953 - learning_rate: 6.2500e-06
# Epoch 47: early stopping
# Restoring model weights from the end of the best epoch: 37.

# %%
test_loss, test_acc = model.evaluate(x_test_flat, y_test, verbose=0)
print(f"\nFinal Test Accuracy: {test_acc:.4f}")
# Out:
# Final Test Accuracy: 0.8961

# %% [markdown]
# **ACCURACY: 89.61%**

# %% [markdown]
# CHANGES:
#
# The number of residual blocks was increased from 2 to over 5 to deepen the network and improve feature learning.
#
# The total number of hidden layers was expanded to more than 10, allowing the model to learn more complex patterns.
#
# The number of neurons in each dense layer was increased from 256/128/64 to a hierarchy like 1024 → 512 → 256 → 128 → 64 for better representation.
#
# The activation function was changed from ReLU to LeakyReLU to avoid the dying neuron problem and allow small gradient flow for negative inputs.
#
# A GaussianNoise layer was added at the input to act as a regularizer and simulate data variability.
#
# Dropout rate was increased from 0.3 to 0.4 within residual blocks to further prevent overfitting.
#
# The optimizer's learning rate was manually tuned to 0.0008 for more stable convergence.
#
# The batch size was reduced from 128 to 64 to increase update frequency and improve generalization.
#
# The training duration was extended from 30 to 60–70 epochs, giving the model more time to learn deeper patterns.
#
# EarlyStopping was added alongside ReduceLROnPlateau to stop training automatically when no further validation improvement was seen.
