# %%
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.datasets import mnist
import matplotlib.pyplot as plt

(x_train, y_train), (x_test, y_test) = mnist.load_data()
x_train = x_train / 255.0
x_test = x_test / 255.0


x_train = x_train.reshape(-1, 28*28)
x_test = x_test.reshape(-1, 28*28)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
model = models.Sequential([
    layers.Dense(512, activation='relu', input_shape=(784,)),
    layers.Dropout(0.2),
    layers.Dense(256, activation='relu'),
    layers.Dense(10, activation='softmax')
])
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# %%
history = model.fit(x_train, y_train, epochs=10, batch_size=128, validation_split=0.1)
test_loss, test_acc = model.evaluate(x_test, y_test)
print(f"\nTest Accuracy: {test_acc:.4f}")

plt.plot(history.history['accuracy'], label='train acc')
plt.plot(history.history['val_accuracy'], label='val acc')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Epoch 1/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 9s 17ms/step - accuracy: 0.8607 - loss: 0.4773 - val_accuracy: 0.9702 - val_loss: 0.0940
# Epoch 2/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 12s 22ms/step - accuracy: 0.9679 - loss: 0.1065 - val_accuracy: 0.9750 - val_loss: 0.0837
# Epoch 3/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 7s 15ms/step - accuracy: 0.9782 - loss: 0.0709 - val_accuracy: 0.9748 - val_loss: 0.0825
# Epoch 4/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 10s 15ms/step - accuracy: 0.9829 - loss: 0.0538 - val_accuracy: 0.9798 - val_loss: 0.0712
# Epoch 5/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 7s 17ms/step - accuracy: 0.9863 - loss: 0.0409 - val_accuracy: 0.9770 - val_loss: 0.0855
# Epoch 6/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 10s 17ms/step - accuracy: 0.9888 - loss: 0.0337 - val_accuracy: 0.9785 - val_loss: 0.0751
# Epoch 7/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 9s 15ms/step - accuracy: 0.9895 - loss: 0.0313 - val_accuracy: 0.9812 - val_loss: 0.0665
# Epoch 8/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 10s 15ms/step - accuracy: 0.9906 - loss: 0.0278 - val_accuracy: 0.9818 - val_loss: 0.0691
# Epoch 9/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 10s 15ms/step - accuracy: 0.9928 - loss: 0.0220 - val_accuracy: 0.9820 - val_loss: 0.0767
# Epoch 10/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 11s 16ms/step - accuracy: 0.9918 - loss: 0.0221 - val_accuracy: 0.9793 - val_loss: 0.0803
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9725 - loss: 0.1029
#
# Test Accuracy: 0.9777

# %%
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.datasets import mnist

(x_train, y_train), (x_test, y_test) = mnist.load_data()

x_train = x_train.reshape(-1, 784).astype("float32") / 255.0
x_test = x_test.reshape(-1, 784).astype("float32") / 255.0

model = models.Sequential([
    layers.Dense(512, activation='relu', input_shape=(784,)),
    layers.Dropout(0.3),
    layers.Dense(256, activation='relu'),
    layers.Dropout(0.3),
    layers.Dense(10, activation='softmax')
])

model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

model.fit(x_train, y_train, epochs=15, batch_size=128, validation_split=0.1)

test_loss, test_acc = model.evaluate(x_test, y_test)
print(f"\n Test Accuracy: {test_acc:.4f}")
# Out:
# Epoch 1/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 9s 18ms/step - accuracy: 0.8318 - loss: 0.5537 - val_accuracy: 0.9723 - val_loss: 0.0987
# Epoch 2/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 10s 18ms/step - accuracy: 0.9588 - loss: 0.1372 - val_accuracy: 0.9747 - val_loss: 0.0860
# Epoch 3/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 9s 15ms/step - accuracy: 0.9709 - loss: 0.0944 - val_accuracy: 0.9805 - val_loss: 0.0679
# Epoch 4/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 8s 18ms/step - accuracy: 0.9774 - loss: 0.0724 - val_accuracy: 0.9798 - val_loss: 0.0701
# Epoch 5/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 10s 18ms/step - accuracy: 0.9811 - loss: 0.0609 - val_accuracy: 0.9823 - val_loss: 0.0613
# Epoch 6/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 9s 15ms/step - accuracy: 0.9827 - loss: 0.0527 - val_accuracy: 0.9848 - val_loss: 0.0582
# Epoch 7/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 7s 18ms/step - accuracy: 0.9850 - loss: 0.0456 - val_accuracy: 0.9813 - val_loss: 0.0689
# Epoch 8/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 7s 16ms/step - accuracy: 0.9871 - loss: 0.0390 - val_accuracy: 0.9832 - val_loss: 0.0590
# Epoch 9/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 10s 15ms/step - accuracy: 0.9880 - loss: 0.0372 - val_accuracy: 0.9837 - val_loss: 0.0614
# Epoch 10/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 7s 18ms/step - accuracy: 0.9886 - loss: 0.0332 - val_accuracy: 0.9823 - val_loss: 0.0698
# Epoch 11/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 11s 18ms/step - accuracy: 0.9899 - loss: 0.0309 - val_accuracy: 0.9838 - val_loss: 0.0587
# Epoch 12/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 9s 15ms/step - accuracy: 0.9900 - loss: 0.0301 - val_accuracy: 0.9852 - val_loss: 0.0630
# Epoch 13/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 10s 15ms/step - accuracy: 0.9904 - loss: 0.0292 - val_accuracy: 0.9823 - val_loss: 0.0729
# Epoch 14/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 10s 15ms/step - accuracy: 0.9911 - loss: 0.0271 - val_accuracy: 0.9833 - val_loss: 0.0696
# Epoch 15/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 11s 17ms/step - accuracy: 0.9902 - loss: 0.0286 - val_accuracy: 0.9843 - val_loss: 0.0673
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9801 - loss: 0.0856
#
#  Test Accuracy: 0.9833

# %%
import tensorflow as tf
from tensorflow.keras import layers, models, callbacks
from tensorflow.keras.datasets import mnist
import matplotlib.pyplot as plt
import numpy as np

(x_train, y_train), (x_test, y_test) = mnist.load_data()
x_train = x_train.reshape(-1, 784).astype("float32") / 255.0
x_test = x_test.reshape(-1, 784).astype("float32") / 255.0

model = models.Sequential([
    layers.Dense(512, activation='relu', kernel_initializer='he_normal', input_shape=(784,)),
    layers.BatchNormalization(),
    layers.Dropout(0.2),
    layers.Dense(256, activation='relu', kernel_initializer='he_normal'),
    layers.BatchNormalization(),
    layers.Dropout(0.2),
    layers.Dense(128, activation='relu', kernel_initializer='he_normal'),
    layers.Dense(10, activation='softmax')
])

model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

early_stop = callbacks.EarlyStopping(patience=3, restore_best_weights=True)

history = model.fit(x_train, y_train, epochs=20, batch_size=128,
                    validation_split=0.1, callbacks=[early_stop])

test_loss, test_acc = model.evaluate(x_test, y_test)
print(f"\nTest Accuracy: {test_acc:.4f}")
predictions = model.predict(x_test)

plt.figure(figsize=(10, 10))
for i in range(25):
    plt.subplot(5, 5, i + 1)
    plt.imshow(x_test[i].reshape(28, 28), cmap='gray')
    pred_label = np.argmax(predictions[i])
    true_label = y_test[i]
    color = 'green' if pred_label == true_label else 'red'
    plt.title(f"Pred: {pred_label}\nTrue: {true_label}", color=color)
    plt.axis('off')
plt.tight_layout()
plt.show()
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/20
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 12s 23ms/step - accuracy: 0.8541 - loss: 0.4701 - val_accuracy: 0.9737 - val_loss: 0.0840
# Epoch 2/20
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 8s 20ms/step - accuracy: 0.9641 - loss: 0.1153 - val_accuracy: 0.9770 - val_loss: 0.0797
# Epoch 3/20
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 9s 21ms/step - accuracy: 0.9741 - loss: 0.0791 - val_accuracy: 0.9763 - val_loss: 0.0780
# Epoch 4/20
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 9s 21ms/step - accuracy: 0.9797 - loss: 0.0634 - val_accuracy: 0.9787 - val_loss: 0.0771
# Epoch 5/20
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 8s 16ms/step - accuracy: 0.9824 - loss: 0.0524 - val_accuracy: 0.9787 - val_loss: 0.0714
# Epoch 6/20
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 11s 18ms/step - accuracy: 0.9833 - loss: 0.0497 - val_accuracy: 0.9805 - val_loss: 0.0751
# Epoch 7/20
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.9862 - loss: 0.0411 - val_accuracy: 0.9805 - val_loss: 0.0708
# Epoch 8/20
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 7s 16ms/step - accuracy: 0.9861 - loss: 0.0411 - val_accuracy: 0.9832 - val_loss: 0.0681
# Epoch 9/20
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 10s 16ms/step - accuracy: 0.9890 - loss: 0.0347 - val_accuracy: 0.9803 - val_loss: 0.0697
# Epoch 10/20
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 11s 18ms/step - accuracy: 0.9880 - loss: 0.0332 - val_accuracy: 0.9815 - val_loss: 0.0723
# Epoch 11/20
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 11s 20ms/step - accuracy: 0.9901 - loss: 0.0290 - val_accuracy: 0.9837 - val_loss: 0.0645
# Epoch 12/20
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 8s 18ms/step - accuracy: 0.9902 - loss: 0.0287 - val_accuracy: 0.9855 - val_loss: 0.0628
# Epoch 13/20
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 8s 18ms/step - accuracy: 0.9915 - loss: 0.0247 - val_accuracy: 0.9838 - val_loss: 0.0719
# Epoch 14/20
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.9914 - loss: 0.0252 - val_accuracy: 0.9835 - val_loss: 0.0733
# Epoch 15/20
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 7s 17ms/step - accuracy: 0.9910 - loss: 0.0256 - val_accuracy: 0.9848 - val_loss: 0.0659
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9778 - loss: 0.0807
#
# Test Accuracy: 0.9819
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step
